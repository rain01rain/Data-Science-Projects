# %% [markdown]
# # Loan

# %% [markdown]
# # Importing packages

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Loading Dataset

# %%
b=pd.read_csv('loan.csv')

# %%
b
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0    LP001015   Male     Yes          0      Graduate            No
# 1    LP001022   Male     Yes          1      Graduate            No
# 2    LP001031   Male     Yes          2      Graduate            No
# 3    LP001035   Male     Yes          2      Graduate            No
# 4    LP001051   Male      No          0  Not Graduate            No
# ..        ...    ...     ...        ...           ...           ...
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0               5720                  0       110.0             360.0
# ...

# %% [markdown]
# # Head

# %%
b.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001015   Male     Yes          0      Graduate            No
# 1  LP001022   Male     Yes          1      Graduate            No
# 2  LP001031   Male     Yes          2      Graduate            No
# 3  LP001035   Male     Yes          2      Graduate            No
# 4  LP001051   Male      No          0  Not Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5720                  0       110.0             360.0
# 1             3076               1500       126.0             360.0
# 2             5000               1800       208.0             360.0
# 3             2340               2546       100.0             360.0
# 4             3276                  0        78.0             360.0
#
#    Credit_History Property_Area
# 0             1.0         Urban
# 1             1.0         Urban
# 2             1.0         Urban
# ...

# %% [markdown]
# # Tail

# %%
b.tail()
# Out:
#       Loan_ID Gender Married Dependents     Education Self_Employed  \
# 362  LP002971   Male     Yes         3+  Not Graduate           Yes
# 363  LP002975   Male     Yes          0      Graduate            No
# 364  LP002980   Male      No          0      Graduate            No
# 365  LP002986   Male     Yes          0      Graduate            No
# 366  LP002989   Male      No          0      Graduate           Yes
#
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 362             4009               1777       113.0             360.0
# 363             4158                709       115.0             360.0
# 364             3250               1993       126.0             360.0
# 365             5000               2393       158.0             360.0
# 366             9200                  0        98.0             180.0
#
#      Credit_History Property_Area
# 362             1.0         Urban
# 363             1.0         Urban
# ...

# %% [markdown]
# # Information

# %%
b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 367 entries, 0 to 366
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            367 non-null    object
#  1   Gender             356 non-null    object
#  2   Married            367 non-null    object
#  3   Dependents         357 non-null    object
#  4   Education          367 non-null    object
#  5   Self_Employed      344 non-null    object
#  6   ApplicantIncome    367 non-null    int64
#  7   CoapplicantIncome  367 non-null    int64
#  8   LoanAmount         362 non-null    float64
#  9   Loan_Amount_Term   361 non-null    float64
#  10  Credit_History     338 non-null    float64
#  11  Property_Area      367 non-null    object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 34.5+ KB

# %% [markdown]
# # Shape

# %%
b.shape
# Out:
# (367, 12)

# %% [markdown]
# # Size

# %%
b.size
# Out:
# 4404

# %% [markdown]
# # Statistical Analysis

# %%
b.describe()
# Out:
#        ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# count       367.000000         367.000000  362.000000        361.000000
# mean       4805.599455        1569.577657  136.132597        342.537396
# std        4910.685399        2334.232099   61.366652         65.156643
# min           0.000000           0.000000   28.000000          6.000000
# 25%        2864.000000           0.000000  100.250000        360.000000
# 50%        3786.000000        1025.000000  125.000000        360.000000
# 75%        5060.000000        2430.500000  158.000000        360.000000
# max       72529.000000       24000.000000  550.000000        480.000000
#
#        Credit_History
# count      338.000000
# mean         0.825444
# std          0.380150
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          1.000000
# max          1.000000

# %% [markdown]
# # Checking Null Values

# %%
b.isnull().sum()
# Out:
# Loan_ID               0
# Gender               11
# Married               0
# Dependents           10
# Education             0
# Self_Employed        23
# ApplicantIncome       0
# CoapplicantIncome     0
# LoanAmount            5
# Loan_Amount_Term      6
# Credit_History       29
# Property_Area         0
# dtype: int64

# %% [markdown]
# # Data Cleaning

# %%
b['Gender']=b['Gender'].replace(to_replace=np.nan,value='no data')

# %%
b['Dependents']=b['Dependents'].fillna(b['Dependents'].mode()[0])

# %%
b['Self_Employed']=b['Self_Employed'].replace(to_replace=np.nan,value='no data')

# %%
b['LoanAmount']=b['LoanAmount'].fillna(b['LoanAmount'].mean())

# %%
b['Loan_Amount_Term']=b['Loan_Amount_Term'].fillna(b['Loan_Amount_Term'].mean())

# %%
b['Credit_History']=b['Credit_History'].fillna(b['Credit_History'].mode()[0])

# %%
b.isnull().sum()
# Out:
# Loan_ID              0
# Gender               0
# Married              0
# Dependents           0
# Education            0
# Self_Employed        0
# ApplicantIncome      0
# CoapplicantIncome    0
# LoanAmount           0
# Loan_Amount_Term     0
# Credit_History       0
# Property_Area        0
# dtype: int64

# %% [markdown]
# # Data Analysis

# %%
sns.relplot(x='ApplicantIncome',y='LoanAmount',data=b)

# %% [markdown]
# Conclusion: High income applicant will have more chances of getting high loan amount.

# %%
sns.pairplot(b)

# %% [markdown]
# Conclusion: Relationship between different components which shows the chances of getting loan.

# %%
sns.relplot(x='ApplicantIncome',y='LoanAmount',data=b,hue='Credit_History')

# %% [markdown]
# Conclusion: Applicants having credit history 1 have higher chances of getting the loan approval.

# %%
sns.relplot(x='ApplicantIncome',y='LoanAmount',data=b,hue='Property_Area')

# %% [markdown]
# Conclusion: Applicants from Urban area have higher chances of getting the loan approval.

# %%
sns.relplot(x='ApplicantIncome',y='LoanAmount',data=b,hue='Gender')

# %% [markdown]
# Conclusion: Male applicants have more chances of getting loan approval compared to female applicants.

# %%
sns.relplot(x='ApplicantIncome',y='LoanAmount',data=b,hue='Married')

# %% [markdown]
# Conclusion: Married applicants have more chances of getting loan approval compared to unmarried applicants.

# %%
sns.relplot(x='ApplicantIncome',y='LoanAmount',data=b,hue='Education')

# %% [markdown]
# Conclusion: Graduate applicants will have more chances of getting loan approval compared to not graduate applicants.

# %%
sns.relplot(x='ApplicantIncome',y='LoanAmount',data=b,hue='Dependents')

# %% [markdown]
# Conclusion: Applicants having less number of dependents have higher chances of getting loan approval.

# %%
sns.relplot(x='ApplicantIncome',y='LoanAmount',data=b,hue='Loan_Amount_Term')

# %% [markdown]
# Conclusion: Applicants having high income have higher chances of getting the loan approval and so they can repay the loan in short loan amount term.

# %%
sns.catplot(x='Credit_History',y='LoanAmount',data=b)

# %% [markdown]
# Conclusion: Applicants having credit history 1 have high chances of getting loan approval.

# %%
sns.catplot(x='Self_Employed',y='LoanAmount',data=b)

# %% [markdown]
# Conclusion: Self employed applicants have less chances of getting the loan approval. Applicants having jobs other than self employment have more chances of getting the loan approval.

# %%
sns.catplot(x='Gender',y='LoanAmount',data=b)

# %% [markdown]
# Conclusion: Male applicants have more chances of getting the loan approval.

# %%
sns.catplot(x='Property_Area',y='LoanAmount',data=b)

# %% [markdown]
# Conclusion: Urban applicants have more chances of getting the loan approval.

# %%
sns.catplot(x='Married',y='LoanAmount',data=b)

# %% [markdown]
# Conclusion: Married applicants have more chances of getting the loan approval.

# %%
sns.catplot(x='Education',y='LoanAmount',data=b)

# %% [markdown]
# Conclusion: Graduate applicants have more chances of getting the loan approval.

# %%
sns.catplot(x='Dependents',y='LoanAmount',data=b)

# %% [markdown]
# Conclusion: Applicants having zero dependents have more chances of getting the loan approval.

# %% [markdown]
# # Conclusion of Data Analysis

# %% [markdown]
# 1.The one whose salary is more can have a greater chance of loan approval.

# %% [markdown]
# 2.The one who is graduate has a better chance of loan approval.

# %% [markdown]
# 3.Married people would have a upper hand than unmarried people for loan approval .

# %% [markdown]
# 4.The applicant who has less number of dependents have a high probability for loan approval.

# %% [markdown]
# 5.The lesser the loan amount the higher the chance for getting loan.

# %% [markdown]
# 6.Self employed applicants have less chances of getting the loan approval.

# %% [markdown]
# 7.Applicants having high income have higher chances of getting the loan approval and so they can repay the loan in short loan amount term.Applicants having credit history one have higher chances of getting loan approval.

# %% [markdown]
# 8.Applicants from urban area have more chances of getting loan approval than other area applicants.

# %% [markdown]
# 9.Male applicants have more chances of getting loan approval than female applicants.

# %% [markdown]
# 10.Applicants having credit history one have higher chances of getting loan approval.
